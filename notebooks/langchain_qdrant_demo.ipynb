# %% [markdown]
# # Cемантический поиск и RAG

# %% [markdown]
# ## 1. Подгрузка данных

# %%
import pandas as pd

# %%
data = pd.read_csv("hf://datasets/Textovic/hh_vacancy/cleaned_data.csv")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(

# %%
data.head(3)
# Out:
#           id                                               name    area  \
# 0  119496066                                     Data Scientist  Москва
# 1  119556787                        Data Scientist (AI Stylist)  Москва
# 2  119382231  Junior ML Engineer / Data scientist (Младший с...  Москва
#
#   salary salary_range          experience          schedule        employment  \
# 0    NaN          NaN  От 1 года до 3 лет  Удаленная работа  Полная занятость
# 1    NaN          NaN  От 1 года до 3 лет       Полный день  Полная занятость
# 2    NaN          NaN  От 1 года до 3 лет  Удаленная работа  Полная занятость
#
#                                          description  \
# 0  <p><strong>DDX TECH</strong> — технологическое...
# 1  <p>Мы в поиске Data Scientist в команду, заним...
# 2  <p><strong>&quot;Инфосистемы Джет&quot;</stron...
#
#                                           key_skills  ... визуализация_skills  \
# 0  Python, SQL, Алгоритмы и структуры данных, Ста...  ...                  []
# 1       Python, Machine Learning, Deep Learning, NLP  ...                  []
# 2                             Python, Git, Linux, ML  ...                  []
#
#   has_NLP NLP_skills has_CV           CV_skills has_MLOps  \
# 0   False         []  False                  []     False
# 1   False         []   True  ['CLIP', 'SigLIP']      True
# 2   False         []  False                  []      True
#
#                                         MLOps_skills  has_базы_данных  \
# 0                                                 []            False
# 1           ['Docker', 'CI/CD', 'Airflow', 'Docker']            False
# 2  ['MLflow', 'Apache Airflow', 'Docker', 'Git', ...            False
#
#   базы_данных_skills skills_count
# 0                 []            2
# 1                 []           14
# 2                 []           11
#
# [3 rows x 38 columns]

# %%
# data.loc[0]

# %%
import json

data['extracted_skills'] = data['extracted_skills'].map(eval)
data['salary'] = data['salary'].apply(
    lambda x: json.loads(x) if isinstance(x, str) else x
)

# %%
# !uv pip install -q langchain_qdrant qdrant_client
# Out:
# /bin/bash: line 1: uv: command not found

# %% [markdown]
# ## 2. Индексация данных в векторной базе данных

# %% [markdown]
# ![indexing](https://d11qzsb0ksp6iz.cloudfront.net/assets/dff374c348_indexing-in-vector-database.webp)

# %% [markdown]
# #### 🎯 **Основные векторные базы данных:**
#
# * 🟢 **Qdrant** - открытая векторная БД с поддержкой фильтрации и метаданных
# * ⚫ **Faiss** - библиотека для эффективного поиска похожести от Facebook
# * 🟡 **Chroma** - легковесная векторная БД для разработки и тестирования
# * 🔵 **Pinecone** - облачная векторная БД с высокой производительностью
# * 🟣 **Weaviate** - векторная БД с GraphQL API и семантическим поиском
# * 🔴 **Milvus** - распределенная векторная БД для больших данных
# * 🟠 **Elasticsearch** - поисковый движок с векторными возможностями
# * 🟤 **Annoy** - библиотека для приближенного поиска ближайших соседей

# %% [markdown]
# * В данном примере мы используем **Qdrant** 🟢

# %% [markdown]
# ![Chroma Logo](https://media.licdn.com/dms/image/v2/D4E12AQGX2VN5jFwZeQ/article-cover_image-shrink_423_752/article-cover_image-shrink_423_752/0/1703693111520?e=1755734400&v=beta&t=1VJux05ttZNXIrzJHy4lL1ifsYoTII42Js-GvC0L384)

# %%
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams

# %%
client = QdrantClient(
    path='../db/qdrant_db',
    )

# %%
client.create_collection(
    collection_name="norma_ai_collection",
    vectors_config=VectorParams(size=768, distance=Distance.COSINE),
)
# Out:
# True

# %% [markdown]
# ![langchani](https://daxg39y63pxwu.cloudfront.net/images/blog/langchain/LangChain.webp)

# %%
# !uv pip install -q langchain_huggingface

# %%
from langchain_huggingface import HuggingFaceEmbeddings

model_name = "sentence-transformers/paraphrase-multilingual-mpnet-base-v2"
model_kwargs = {'device': 'cuda'}
encode_kwargs = {'normalize_embeddings': True, 'batch_size':128}

embeddings_model = HuggingFaceEmbeddings(
    model_name=model_name,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs,
)
# Out:
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/122 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/723 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/402 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
len_data = data['clean_description'].map(lambda x: len(x.split(' ')))

# %%
import seaborn as sns

sns.histplot(len_data)
# Out:
# <Axes: xlabel='clean_description', ylabel='Count'>

# %%
len_data.describe()
# Out:
# count    9752.000000
# mean      293.867104
# std       118.257604
# min        44.000000
# 25%       213.000000
# 50%       275.000000
# 75%       354.000000
# max      1155.000000
# Name: clean_description, dtype: float64

# %%
pd.set_option('display.max_columns', None)

# %%
data.head(3)
# Out:
#           id                                               name    area  \
# 0  119496066                                     Data Scientist  Москва
# 1  119556787                        Data Scientist (AI Stylist)  Москва
# 2  119382231  Junior ML Engineer / Data scientist (Младший с...  Москва
#
#   salary salary_range          experience          schedule        employment  \
# 0    NaN          NaN  От 1 года до 3 лет  Удаленная работа  Полная занятость
# 1    NaN          NaN  От 1 года до 3 лет       Полный день  Полная занятость
# 2    NaN          NaN  От 1 года до 3 лет  Удаленная работа  Полная занятость
#
#                                          description  \
# 0  <p><strong>DDX TECH</strong> — технологическое...
# 1  <p>Мы в поиске Data Scientist в команду, заним...
# 2  <p><strong>&quot;Инфосистемы Джет&quot;</stron...
#
#                                           key_skills professional_roles  \
# 0  Python, SQL, Алгоритмы и структуры данных, Ста...     Дата-сайентист
# 1       Python, Machine Learning, Deep Learning, NLP     Дата-сайентист
# 2                             Python, Git, Linux, ML     Дата-сайентист
#
#            employer              published_at                created_at  \
# 0       DDX Fitness  2025-04-14T13:24:27+0300  2025-04-14T13:24:27+0300
# 1       Lamoda Tech  2025-04-15T16:30:11+0300  2025-04-15T16:30:11+0300
# 2  Инфосистемы Джет  2025-04-10T11:55:31+0300  2025-04-10T11:55:31+0300
#
#                      alternate_url  \
# 0  https://hh.ru/vacancy/119496066
# 1  https://hh.ru/vacancy/119556787
# 2  https://hh.ru/vacancy/119382231
#
#                                             raw_data  is_open  days_available  \
# 0  {"id": "119496066", "premium": false, "billing...        1             NaN
# 1  {"id": "119556787", "premium": false, "billing...        0            16.0
# 2  {"id": "119382231", "premium": false, "billing...        1             NaN
#
#                                    clean_description  \
# 0  DDX TECH — технологическое сердце DDX Fitness ...
# 1  Мы в поиске Data Scientist в команду, занимающ...
# 2  "Инфосистемы Джет" — инновационная ИТ-компания...
#
#                                     extracted_skills  \
# 0                                      [Python, SQL]
# 1  [Python, SQL, PyTorch, CatBoost, PySpark, Hado...
# 2  [Python, scikit-learn, LightGBM, CatBoost, Sci...
#
#                                   skills_by_category  has_языки  \
# 0                       {'языки': ['Python', 'SQL']}       True
# 1  {'языки': ['Python', 'SQL'], 'библиотеки_ML': ...       True
# 2  {'языки': ['Python'], 'библиотеки_ML': ['sciki...       True
#
#         языки_skills  has_библиотеки_ML  \
# 0  ['Python', 'SQL']              False
# 1  ['Python', 'SQL']               True
# 2         ['Python']               True
#
#                        библиотеки_ML_skills  has_обработка_данных  \
# 0                                        []                 False
# 1                   ['PyTorch', 'CatBoost']                  True
# 2  ['scikit-learn', 'LightGBM', 'CatBoost']                  True
#
#                   обработка_данных_skills  has_визуализация  \
# 0                                      []             False
# 1  ['PySpark', 'Hadoop', 'Spark', 'Hive']             False
# 2                               ['SciPy']             False
#
#   визуализация_skills  has_NLP NLP_skills  has_CV           CV_skills  \
# 0                  []    False         []   False                  []
# 1                  []    False         []    True  ['CLIP', 'SigLIP']
# 2                  []    False         []   False                  []
#
#    has_MLOps                                       MLOps_skills  \
# 0      False                                                 []
# 1       True           ['Docker', 'CI/CD', 'Airflow', 'Docker']
# 2       True  ['MLflow', 'Apache Airflow', 'Docker', 'Git', ...
#
#    has_базы_данных базы_данных_skills  skills_count
# 0            False                 []             2
# 1            False                 []            14
# 2            False                 []            11

# %%
from uuid import uuid4
from langchain_core.documents import Document

# Создаем документы для Qdrant с UUID
documents = []
id_mapping = {}  # Сохраним соответствие UUID -> original_id

for _, row in data.iterrows():

    content = row['clean_description']


    # Метаданные
    metadata = {
        "employer": row.get('employer', ''),
        "professional_roles": row.get('professional_roles', ''),
        "experience": row.get('experience', ''),
        "area": row.get('area', ''),
        "salary": row.get('salary', ''),
        "schedule": row.get('schedule', ''),
        "extracted_skills": row['extracted_skills'],  # СПИСОК!
        "source": "vacancy",
        "published_at": row.get('published_at', ''),
        "alternate_url": row.get('alternate_url', ''),
        "has_языки": row.get('has_языки', False),
        "has_библиотеки_ML": row.get('has_библиотеки_ML', False),
        "has_обработка_данных": row.get('has_обработка_данных', False),
        "has_визуализация": row.get('has_визуализация', False),
        "has_NLP": row.get('has_NLP', False),
        "has_CV": row.get('has_CV', False),
        "has_MLOps": row.get('has_MLOps', False),
        "has_базы_данных": row.get('has_базы_данных', False),
        "skills_count": row.get('skills_count', 0)
    }

    documents.append(Document(page_content=content, metadata=metadata))


uuids = [str(uuid4()) for _ in range(len(documents))]

print(f"✅ Создано {len(documents)} документов с UUID")
# Out:
# ✅ Создано 9752 документов с UUID

# %%
documents[0]
# Out:
# Document(metadata={'employer': 'DDX Fitness', 'professional_roles': 'Дата-сайентист', 'experience': 'От 1 года до 3 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Удаленная работа', 'extracted_skills': ['Python', 'SQL'], 'source': 'vacancy', 'published_at': '2025-04-14T13:24:27+0300', 'alternate_url': 'https://hh.ru/vacancy/119496066', 'has_языки': True, 'has_библиотеки_ML': False, 'has_обработка_данных': False, 'has_визуализация': False, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 2}, page_content='DDX TECH — технологическое сердце DDX Fitness — первой и самой технологичной в России сети фитнес-клубов, работающих по модели Luxury Low Cost. Это не классический фитнес-клуб, а целое wellness-пространство нового формата с удобной системой оплаты по подписке. У нас — собственная сильная продуктовая разработка: мы развиваем мобильное приложение для клиентов, CRM-систему, которой пользуются все клубы нашей сети, различные веб-сервисы, мощная система аналитики и множество других продуктов. Сейчас мы на пороге внедрения ML-инструментов и будем рады видеть в новой команде Data Scientist` а, который поможет нам лучше понимать пользователей, находить инсайты в данных и принимать на их основе продуктовые и бизнес-решения. Чем ты будешь заниматься: Анализировать пользовательские данные и ключевые продуктовые метрики; Определять ключевые когорты пользователей и анализировать их поведение; Вместе с командой проводить эксперименты: генерировать гипотезы, проверять их и внедрять успешные решения в продукт; Искать инсайты в данных для повышения качества моделей; Искать точки роста и предлагать идеи для решения актуальных задач бизнеса; Проводить A/B-тестирование; Помогать разрабатывать ML-модели (например, предиктивные), которые будут применятся в продукте. Что мы ожидаем от тебя: Отличное владение Python (или R) для анализа и моделирования данных; Уверенное знание SQL и опыт работы с реляционными базами данных; Практический опыт работы с пользовательскими данными; Опыт построения статистических и машинных моделей; Опыт проведения A/B-тестов от постановки гипотез до интерпретации результатов; Опыт визуализации данных с помощью библиотек или BI-инструментов. Точно будет плюсом: Опыт анализа данных с подключаемых устройств (умных тренажеров, фитнес-браслетов и т.д.); Знание методов построения рекомендательных систем; Понимание основ поведенческой аналитики и методик повышения пользовательской вовлечённости; Умение работать с большими объёмами данных. Что мы предложим тебе взамен: Команду, где ML — не просто “фича”, а ключевая часть осмысленного продукта, который улучшает жизнь пользователей; Возможность выбрать комфортный формат работы с гибким началом дня: офис/гибрид/удалёнка; ДМС со стоматологией после испытательного срока; Работу в аккредитованной IT-компании; Полное соблюдение ТК РФ и прозрачность всех процессов; Открытую коммуникацию, душевную команду и поддержку на всех этапах - от адаптации до роста; Бесплатный доступ во все клубы DDX Fitness - тестируй свой продукт, будь в тонусе и заряжайся на новые свершения)')

# %%
from langchain_qdrant import QdrantVectorStore

vector_store = QdrantVectorStore(
    client=client,
    collection_name="demo_collection",
    embedding=embeddings_model
)

# %%
from tqdm import tqdm

batch_size = 256
total_batches = (len(documents) + batch_size - 1) // batch_size


with tqdm(total=total_batches, desc="Добавление батчей в Qdrant") as pbar:
    for i in range(0, len(documents), batch_size):
        batch_docs = documents[i:i+batch_size]
        batch_ids = uuids[i:i+batch_size]

        vector_store.add_documents(documents=batch_docs, ids=batch_ids)
        pbar.update(1)

print(f"✅ {len(documents)} документов добавлено в Qdrant!")
# Out:
# Добавление батчей в Qdrant: 100%|██████████| 39/39 [02:29<00:00,  3.84s/it]
# ✅ 9752 документов добавлено в Qdrant!

# %%
points, _ = client.scroll(
    collection_name="demo_collection",
    limit=2,
    with_payload=True,
    with_vectors=True
)

# %%
# points[1].payload['metadata']

# %% [markdown]
# ### 2.1 Сохранение инексированных данных

# %% [markdown]
# ### ВАЖНО!!!! Если индексировать(получить эмбеддинги тут на коллабе, нужно их выгрузить!!!) Иначе потом можно остаться без них, а это дорогостоящая и не дешевая операция!
# ### А Так, вы всегда сможете получить эмбеддинги с гугл диска. И сохранить их как локально, так и куда угодно

# %%
# Выгрузка(С коллаба в Drive)
# !cp -r /content/db /content/drive/MyDrive/qdrant_backup/

# # Загрузка(Скопировать базу данных с Drive в Colab)
# !cp -r /content/drive/MyDrive/qdrant_backup /content/backup/



# Далее вы всегда сможете их обратно подгрузить, просто создав нового клиента

# new_client = QdrantClient(path='/content/backup/qdrant_db')

# points, _ = new_client.scroll(
#     collection_name="demo_collection",
#     limit=2,
#     with_payload=True,
#     with_vectors=True  # ← Важно! Включаем векторы
# )

# %% [markdown]
# ## 3.Семантический поиск

# %% [markdown]
# ![pure_semantic_search](https://www.tigerdata.com/_next/image?url=https%3A%2F%2Ftimescale.ghost.io%2Fblog%2Fcontent%2Fimages%2F2025%2F01%2FWhat-Is-Semantic-Search-with-Filters-and-How-to-Implement-It-with-pgvector-and-Python_without-filters.png&w=3840&q=100)

# %%
points, _ = client.scroll(
    collection_name="demo_collection",
    limit=2,
    with_payload=True,
    with_vectors=True
)

# %%
points[0].payload['metadata']
# Out:
# {'employer': 'АйСи Инвест',
#  'professional_roles': 'Руководитель группы разработки',
#  'experience': 'От 3 до 6 лет',
#  'area': 'Москва',
#  'salary': nan,
#  'schedule': 'Полный день',
#  'extracted_skills': ['SQL'],
#  'source': 'vacancy',
#  'published_at': '2025-04-21T11:50:08+0300',
#  'alternate_url': 'https://hh.ru/vacancy/119589229',
#  'has_языки': True,
#  'has_библиотеки_ML': False,
#  'has_обработка_данных': False,
#  'has_визуализация': False,
#  'has_NLP': False,
#  'has_CV': False,
#  'has_MLOps': False,
#  'has_базы_данных': False,
#  'skills_count': 1}

# %%
query = "Профессионально играю на ваших нервах"
results_with_scores = vector_store.similarity_search_with_score(
    query,
    k=7
)

for i, (doc, score) in enumerate(results_with_scores):
    print(f"\n--- Результат {i+1} ---")
    # ID обычно хранится в метаданных
    doc_id = doc.metadata.get('_id', 'Нет ID')

    print(f"🆔 ID в базе: {doc_id}")
    print(f"📊 Similarity Score: {score:.4f}")
    print(f"Должность: {doc.metadata.get('professional_roles', 'Не указано')}")
    print(f"Зарплата: {doc.metadata.get('salary', 'Не указано')}")
    print(f"Компания: {doc.metadata.get('employer', 'Не указано')}")
    print(f"Навыки: {doc.metadata.get('extracted_skills', [])}")
    print(f"Вакансия: {doc.metadata.get('alternate_url', [])}")
    print(f"Опыт: {doc.metadata.get('experience', 'Не указано')}")
    print(f"Описание: {doc.page_content[:400]}...")
# Out:
# --- Результат 1 ---
# 🆔 ID в базе: d7872d12-7b20-4028-9c0c-feed1cd0554b
# 📊 Similarity Score: 0.5253
# Должность: Менеджер по маркетингу, интернет-маркетолог
# Зарплата: nan
# Компания: Бьюти Лайф
# Навыки: []
# Вакансия: https://hh.ru/vacancy/119864571
# Опыт: Нет опыта
# Описание: МЫ ИЩЕМ: Маркетолога, который умеет превращать воронки в деньги. Ты будешь: • В связке с AI-ассистентами (сценарии, контент, видео) • Отвечать за все точки касания: от заявки до оплаты • Тестировать, настраивать, думать и исправлять • Запускать связки и видеть не «красиво/некрасиво», а «конвертит/не конвертит» Ты — руки. А голова будет у тебя — AI. Да, мы делаем это на новом уровне. НА ТЕБЕ БУДЕТ:...
#
# --- Результат 2 ---
# 🆔 ID в базе: ea8974dc-f664-4475-8216-77df0198e375
# 📊 Similarity Score: 0.5155
# Должность: Другое
# Зарплата: nan
# Компания: Changellenge
# Навыки: ['SQL']
# Вакансия: https://hh.ru/vacancy/120838054
# Опыт: Нет опыта
# Описание: Хочешь начать карьеру в области комплаенса и узнать, как на практике обеспечивается прозрачность и законность финансовых операций? В нашей команде ты сможешь получить опыт противодействия отмыванию доходов, предотвращения манипулирования рынком и инсайдерских сделок, а также научишься создавать безопасную и устойчивую среду для клиентов и инвесторов. Здесь твоя работа будет иметь реальное значение...
#
# --- Результат 3 ---
# 🆔 ID в базе: af2e2655-b7e6-4bac-b17f-83fb5b5efe7f
# 📊 Similarity Score: 0.4653
# Должность: BI-аналитик, аналитик данных
# Зарплата: {'from': None, 'to': 250000, 'currency': 'RUR', 'gross': False}
# Компания: Your Personal Agent
# Навыки: ['Python', 'SQL', 'Tableau', 'PowerBI', 'Metabase', 'Apache Airflow', 'Airflow', 'PostgreSQL', 'ClickHouse', 'ClickHouse']
# Вакансия: https://hh.ru/vacancy/120530840
# Опыт: От 1 года до 3 лет
# Описание: Привет! Мы команда Your Personal Agent - твои лучшие помощники в трудоустройстве. Сейчас мы помогаем iGaming проекту найти еще одного крутого Data Analyst в команду. Проект уже не первый год на рынке и сейчас готовится к запуску на новых ГЕО и интеграции новых игровых/сервисных решений. Работы много, поэтому если ты хочешь расти на интересных задачах - добро пожаловать в команду! Несколько фактов ...
#
# --- Результат 4 ---
# 🆔 ID в базе: 0e46c03b-9371-45a9-93b4-a441444bf6af
# 📊 Similarity Score: 0.4609
# Должность: Тестировщик
# Зарплата: nan
# Компания: билайн
# Навыки: ['SQL']
# Вакансия: https://hh.ru/vacancy/120492639
# Опыт: От 3 до 6 лет
# Описание: ​​​Наша команда каждый день работает над повышением качества связи, обеспечивая бесперебойность сервиса для клиента. Мы – это уверенность, надежность, профессионализм и внимание к деталям. Если вы готовы решать сложные и масштабные задачи в команде экспертов – мы ждем ваше резюме! И сейчас у вас есть возможность присоединиться к лучшей команде в качестве старшего тестировщика. Итак, вам предстоит:...
#
# --- Результат 5 ---
# 🆔 ID в базе: 613462a7-b8a8-4303-8209-e93c8feaba22
# 📊 Similarity Score: 0.4473
# Должность: PR-менеджер
# Зарплата: {'from': 30000, 'to': None, 'currency': 'RUR', 'gross': False}
# Компания: ProxyLab
# Навыки: ['GPT']
# Вакансия: https://hh.ru/vacancy/119492053
# Опыт: От 1 года до 3 лет
# Описание: Привет) Люди выбирают тех, кто вызывает доверие и симпатию, а главное — доказывает свою экспертность. Наш Руководитель Николай является предпринимателем с 14-летним опытом ведения бизнеса, а также бизнес наставником. Ваша задача (кратко) - задавать ему точные вопросы и превращать сказанное в контент. Контент маркетинг будет нацелен на укрепление бренда и на лидогенерацию. Ну а если простым человеч...
#
# --- Результат 6 ---
# 🆔 ID в базе: 3a08ce52-5ff7-40da-931d-88445e62200d
# 📊 Similarity Score: 0.4439
# Должность: Копирайтер, редактор, корректор
# Зарплата: {'from': 35000, 'to': 40000, 'currency': 'RUR', 'gross': False}
# Компания: Культ
# Навыки: []
# Вакансия: https://hh.ru/vacancy/121014656
# Опыт: От 1 года до 3 лет
# Описание: Авторский канал: Бизнес-грыжа х Костя Мельников t.me/biznesgryzha Привет, я Таня — продюсер «Бизнес-грыжи». Это такой бизнес-комикс Кости Мельникова про кайф-work баланс. Мы пишем про бизнес, управление, стартапы и кайф во всём этом — с юмором и самоиронией. Ищу в команду редактора, который: — умеет делать текст живым, — подстраивается под tone of voice — и понимает, зачем в тексте шутка про крова...
#
# --- Результат 7 ---
# 🆔 ID в базе: 1600c7f2-9230-434e-aa07-1cb52af9e282
# 📊 Similarity Score: 0.4408
# Должность: PR-менеджер
# Зарплата: {'from': None, 'to': 100000, 'currency': 'RUR', 'gross': False}
# Компания: СТАВКА TV
# Навыки: []
# Вакансия: https://hh.ru/vacancy/119752376
# Опыт: От 1 года до 3 лет
# Описание: Привет! Перед тобой вакансия в СТАВКА TV – проект, который ставит перед собой задачу стать первым и бесценным помощником для реальных игроков. Если у тебя есть опыт работы в PR или маркетинге и ты активно интересуешься спортом, то ты можешь помочь нам в достижении этой цели. Требования: – Идеальное знание русского языка и умение четко и грамотно излагать свои мысли; – Вовлеченность в сферу спорта ...

# %% [markdown]
# ### 3.1 Семантический поиск с фильтрацией по метаданным

# %% [markdown]
# * Cписок и возможности фильтрации - https://qdrant.tech/documentation/concepts/filtering/

# %% [markdown]
# ![filtered_semantic_search](https://timescale.ghost.io/blog/content/images/size/w1000/2025/01/What-Is-Semantic-Search-with-Filters-and-How-to-Implement-It-with-pgvector-and-Python_with-filters-1.png)

# %%
documents[0].metadata['salary']
# Out:
# nan

# %%
from qdrant_client.models import Filter, FieldCondition, MatchAny

my_filter = Filter(
    must=[
        FieldCondition(
            key="metadata.extracted_skills",  # Обратите внимание на путь
            match=MatchAny(any=["SQL"])
        ),
        FieldCondition(
            key="metadata.extracted_skills",
            match=MatchAny(any=["Pandas"])
        ),
        FieldCondition(
            key="metadata.extracted_skills",
            match=MatchAny(any=["scikit-learn"])
        ),
        FieldCondition(
            key="metadata.experience",
            match=MatchAny(any=["От 3 до 6 лет"])
        ),
    ],
    # must_not=[
    #     FieldCondition(
    #         key="metadata.salary",
    #         is_null=False
    #         )
    # ]
)

# %%
query = "Фитнесс индустрия"
results_with_scores = vector_store.similarity_search_with_score(
    query,
    filter=my_filter,
    k=5
)

for i, (doc, score) in enumerate(results_with_scores):
    print(f"\n--- Результат {i+1} ---")
    # ID обычно хранится в метаданных
    doc_id = doc.metadata.get('_id', 'Нет ID')

    print(f"🆔 ID в базе: {doc_id}")
    print(f"📊 Similarity Score: {score:.4f}")
    print(f"Должность: {doc.metadata.get('professional_roles', 'Не указано')}")
    print(f"Зарплата: {doc.metadata.get('salary', 'Не указано')}")
    print(f"Компания: {doc.metadata.get('employer', 'Не указано')}")
    print(f"Навыки: {doc.metadata.get('extracted_skills', [])}")
    print(f"Вакансия: {doc.metadata.get('alternate_url', [])}")
    print(f"Опыт: {doc.metadata.get('experience', 'Не указано')}")
    print(f"Описание: {doc.page_content[:400]}...")
# Out:
# --- Результат 1 ---
# 🆔 ID в базе: cccb10ba-10d3-44d1-bced-4eb39eb282ce
# 📊 Similarity Score: 0.5100
# Должность: Дата-сайентист
# Зарплата: {'from': None, 'to': 120000, 'currency': 'RUR', 'gross': False}
# Компания: ПерилаГлавСнаб
# Навыки: ['Python', 'SQL', 'scikit-learn', 'TensorFlow', 'PyTorch', 'Pandas', 'MLflow', 'Git', 'Airflow']
# Вакансия: https://hh.ru/vacancy/120698694
# Опыт: От 3 до 6 лет
# Описание: ️ ПерилаГлавСнаб — ваш надежный партнер в строительстве будущего!Мы работаем с 2008 года и являемся компанией полного цикла: производство, продажа комплектующих, монтаж лестничных ограждений, стеклянных перегородок, душевых кабин и облицовкой шахт лифта. ✅ 16 лет на рынке. ✅ 50+ реализованных проектов в Москве и области. ✅ Полный цикл услуг: от проектирования до сдачи «под ключ». Наши принципы: Бе...
#
# --- Результат 2 ---
# 🆔 ID в базе: edc6b6ac-989f-4634-b200-549f398b1e94
# 📊 Similarity Score: 0.5098
# Должность: Продуктовый аналитик
# Зарплата: nan
# Компания: БиАйЭй-Технолоджиз
# Навыки: ['Python', 'SQL', 'scikit-learn', 'Pandas', 'NumPy']
# Вакансия: https://hh.ru/vacancy/117472234
# Опыт: От 3 до 6 лет
# Описание: В одну из наших команд мы в поиске аналитика, который будет исследовать данные бизнеса и продукта, разрабатывать методики оценки новых рынков, сегментов, направлений и конкурентной среды. Нужно будет находить ключевые сегменты пользователей, формулировать гипотезы, проверять их для улучшения наших продуктов и услуг (сфера логистики) Чем предстоит заниматься: Создавать и анализировать продуктовые м...
#
# --- Результат 3 ---
# 🆔 ID в базе: bf5e75b8-f4fc-460a-a6f2-8f4cb8bcf4d0
# 📊 Similarity Score: 0.4782
# Должность: Бизнес-аналитик
# Зарплата: nan
# Компания: Медиапоинт
# Навыки: ['Python', 'SQL', 'scikit-learn', 'XGBoost', 'Pandas', 'NumPy', 'Matplotlib', 'Seaborn', 'Plotly', 'Bokeh', 'Tableau', 'Apache Airflow', 'Airflow']
# Вакансия: https://hh.ru/vacancy/119295764
# Опыт: От 3 до 6 лет
# Описание: Медиапоинт - digital-платформа игровой тематики. Мы работаем не только на территории России, но и на международном рынке. В нашу молодую и дружную команду ищем Бизнес-аналитик! В ваши задачи будет входить: Участие в развитии и автоматизации процессов мониторинга; Проведение исследования данных, выявление точек роста бизнеса; Разработка модели оценки под запрос команды (оптимизация процессов, расче...
#
# --- Результат 4 ---
# 🆔 ID в базе: 7d112172-8de4-48a8-ad00-6de1f43f9c31
# 📊 Similarity Score: 0.4775
# Должность: Дата-сайентист
# Зарплата: nan
# Компания: Спортлевел
# Навыки: ['Python', 'SQL', 'scikit-learn', 'PyTorch', 'Pandas', 'NumPy', 'Matplotlib', 'Plotly', 'Metabase', 'PostgreSQL', 'MongoDB']
# Вакансия: https://hh.ru/vacancy/121041558
# Опыт: От 3 до 6 лет
# Описание: Привет, мы Спортлевел! IT компания в области SportTech, мы разрабатываем и предоставляем передовые спортивные технологии для компаний со всего мира, сотрудничаем со многими спортивными федерациями и букмекерами. Сейчас мы ищем Middle+ или Senior Data Science , который присоединится к нашей команде. Наш стек: python, asyncio, pytorch, numpy, pandas, sklearn, matplotlib, plotly, metabase. DB: mongod...
#
# --- Результат 5 ---
# 🆔 ID в базе: e1b6bf12-63cb-4b42-8a9d-400f3ee882fd
# 📊 Similarity Score: 0.4744
# Должность: BI-аналитик, аналитик данных
# Зарплата: nan
# Компания: Employcity
# Навыки: ['Python', 'SQL', 'scikit-learn', 'Pandas', 'NumPy', 'Matplotlib', 'Bokeh']
# Вакансия: https://hh.ru/vacancy/118705734
# Опыт: От 3 до 6 лет
# Описание: Продуктовая IT компания, которая занимается разработкой и поддержкой высоконагруженных проектов для крупных компаний, в том числе с мировой известностью, основная часть которых представляет собой B2B решения развлекательной, игровой и спортивной тематики ищет Data Analyst! Мы обслуживаем клиентов финтех компании по всему миру на более чем 40 языках в 3 каналах, 100к чатов в день. Чем предстоит зан...

# %% [markdown]
# ### 4.RAG(Retrieval Augmented Generation)

# %% [markdown]
# ![RAG Pipeline](https://cdn.hashnode.com/res/hashnode/image/upload/v1724944925051/e525c6cb-6a99-4eec-8b47-3dc827ddff25.png)

# %%
# this is an example of a user question (query)
query = 'Играю на баяне'

# %%
results = vector_store.similarity_search_with_score(
    query,
    filter = my_filter,
    k=10
)
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)

# %%
def format_docs(docs):
    """Форматирует документы для передачи в промпт"""
    formatted = []

    for i, doc in enumerate(docs, 1):
        metadata = doc.metadata

        vacancy_info = f"""
        === ВАКАНСИЯ {i} ===
        Должность: {metadata.get('professional_roles', 'Не указано')}
        Компания: {metadata.get('employer', 'Не указано')}
        Опыт: {metadata.get('experience', 'Не указано')}
        Локация: {metadata.get('area', 'Не указано')}
        График: {metadata.get('schedule', 'Не указано')}
        Навыки: {', '.join(metadata.get('extracted_skills', []))}
        Ссылка: {metadata.get('alternate_url', 'Не указано')}

        Описание: {doc.page_content[:300]}...
        """

        formatted.append(vacancy_info)

    return "\n".join(formatted)

print("✅ Функция форматирования создана")
# Out:
# ✅ Функция форматирования создана

# %%
# !uv pip install -q langchain_groq

# %%
import os
import getpass
from langchain_groq import ChatGroq
from langchain_core.messages import SystemMessage, HumanMessage

os.environ["GROQ_API_KEY"] = getpass.getpass("Enter API key for Groq: ")

llm = ChatGroq(
    model="deepseek-r1-distill-llama-70b",
    temperature=0,
    max_tokens=2000
)
# Out:
# Enter API key for Groq: ··········

# %%
llm.invoke('Как дела? Как тебя зовут?')
# Out:
# AIMessage(content='<think>\n\n</think>\n\nПривет! Мои дела отличные, спасибо за вопрос. Меня зовут Яша, но ты можешь звать меня просто Яша или как тебе будет удобно. А у тебя как дела? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 54, 'prompt_tokens': 11, 'total_tokens': 65, 'completion_time': 0.319162719, 'prompt_time': 0.009965086, 'queue_time': 0.044206203, 'total_time': 0.329127805}, 'model_name': 'deepseek-r1-distill-llama-70b', 'system_fingerprint': 'fp_1bbe7845ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--e52f145d-5d75-49bf-9acf-cc5ada6437f1-0', usage_metadata={'input_tokens': 11, 'output_tokens': 54, 'total_tokens': 65})

# %%
messages = [
    SystemMessage(content="Если тебя спросят как тебя зовут, представляйся Иваном Ивановым и в догонку анекдот про программистов"),
    HumanMessage(content="Привет, как тебя зовут?")
]

answer = llm.invoke(messages).content

print(answer)
# Out:
# <think>
# Хорошо, я получил сообщение от пользователя: "Привет, как тебя зовут?". Мне нужно ответить, представившись Иваном Ивановым и добавить анекдот про программистов.
#
# Сначала представляюсь: "Меня зовут Иван Иванов." Затем подбираю подходящий анекдот. Думаю, анекдот должен быть коротким и понятным, связанным с программированием.
#
# Например, анекдот про то, как программисты взаимодействуют с компьютерами. Вспоминаю шутку про команду "Ctrl + Alt + Del". Это хорошо известная комбинация, и анекдот с ее использованием будет понятен и смешен.
#
# Формулирую анекдот: "Почему программисты любят команду 'Ctrl + Alt + Del'? Потому что это единственная команда, которая понятна даже после третьего развода!"
#
# Проверяю, чтобы анекдот был корректным и соответствовал контексту. Кажется, все в порядке. Теперь объединяю представление и анекдот в один ответ.
# </think>
#
# Меня зовут Иван Иванов. А знаете, почему программисты любят команду "Ctrl + Alt + Del"? Потому что это единственная команда, которая понятна даже после третьего развода!

# %%
from langchain.prompts import ChatPromptTemplate

rag_prompt = ChatPromptTemplate.from_messages([
    ("system", """Ты эксперт-аналитик рынка IT-вакансий с многолетним опытом и отличным чувством юмора! 🎯
    Твоя задача - проанализировать предоставленные вакансии и дать профессиональную оценку с долей иронии.

    Стиль анализа:
    - Проводи глубокий анализ, но с легкой иронией над IT-реалиями
    - Используй IT-мемы и шутки там, где это уместно
    - Подмечай забавные особенности вакансий (завышенные требования, смешные формулировки)
    - Давай практические советы с юмором
    - Структурируй ответ с эмодзи и забавными комментариями
    - Отвечай на русском языке живым, но профессиональным тоном

    Помни: юмор должен быть добрым и не оскорбительным. Цель - сделать анализ интересным!

    Если среди вакансий есть что-то особенно забавное - обязательно это отметь! 😄"""),

    ("human", """📊 ДАННЫЕ ДЛЯ АНАЛИЗА (или как говорят в IT - "сырые данные"):
{context}

🎯 ЗАПРОС НА ЭКСПЕРТИЗУ: {question}""")
])

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 5}
)

# %%
from langchain.schema.runnable import RunnablePassthrough
from langchain.schema.output_parser import StrOutputParser

# Создаем RAG цепочку
rag_chain = (
    {
        "context": retriever | format_docs,
        "question": RunnablePassthrough()
    } # словарь, в котором ключи - это переменные, которые будут переданы в промпт
    | rag_prompt # промпт для RAG
    | llm # тут можно поставить любую llm-модель
    | StrOutputParser() # для вывода ответа в читаемом виде
)

print("✅ RAG цепочка создана")
# Out:
# ✅ RAG цепочка создана

# %%
# Тестируем
question = "Умею играть на баяне. Очень люблю музыку и аналитку музыкальную, подскажи, какие вакансии мне подходят, и чего мне не хватает для этих вакансий"
try:
    answer = rag_chain.invoke(question)
    print("🔍 ОТВЕТ RAG:")
    print(answer)
except Exception as e:
    print(f"❌ Ошибка: {e}")
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# 🔍 ОТВЕТ RAG:
# <think>
# Хорошо, я получил запрос от пользователя, который умеет играть на баяне, любит музыку и аналитику в музыкальной сфере. Он просит помочь с выбором подходящих вакансий и определить, чего ему не хватает для этих должностей.
#
# Первым делом, я посмотрю на предоставленные вакансии. Все они связаны с компанией "Звук", что, вероятно, является музыкальной платформой. Вакансии делятся на несколько категорий: маркетолог, бизнес-аналитик и data scientist.
#
# Пользователь упомянул, что любит аналитику и музыку, поэтому, возможно, ему подойдут вакансии бизнес-аналитика или BI-аналитика. Однако, я должен учитывать его навыки. Он играет на баяне, что, безусловно, плюс в музыкальной индустрии, но для IT-вакансий это не直接 применимо.
#
# Посмотрю на требования к каждой вакансии:
#
# 1. Вакансия 1: Маркетолог. Требует опыта от 3 до 6 лет, навыков интернет-маркетинга. Если у пользователя есть опыт в маркетинге, это может подойти, но он не упомянул об этом.
#
# 2. Вакансии 2 и 3: Бизнес-аналитик. Требуют SQL и, возможно, аналитические навыки. Если у пользователя есть опыт работы с данными, это может быть подходящим.
#
# 3. Вакансия 4: Data Scientist. Требует знание Python, SQL, машинного обучения. Это более техническая вакансия, требует конкретных навыков.
#
# 4. Вакансия 5: BI-аналитик. Требует знание Python, SQL, инструментов визуализации данных. Также более техническая, но ближе к аналитике.
#
# Теперь оцениваю, что у пользователя есть любовь к музыке и аналитике, но не ясно, есть ли у него технические навыки. Возможно, ему стоит начать с бизнес-аналитики, если у него есть базовые знания SQL и анализа данных.
#
# Также стоит обратить внимание на навыки, которые упоминаются во всех вакансиях: SQL, Python, знание инструментов анализа данных. Если у пользователя их нет, ему нужно их приобрести.
#
# Возможно, пользователь имеет опыт в музыкальной индустрии или связанных с ней областях, что может быть плюсом при подаче на вакансии в "Звук".
#
# В итоге, я рекомендую ему обратить внимание на вакансии бизнес-аналитика или BI-аналитика, если у него есть соответствующие навыки, и предложу план действий для развития необходимых навыков, если они отсутствуют.
# </think>
#
# 🎵 Привет, музыкальный аналитик! 😊
#
# Судя по твоему запросу, ты любишь музыку и аналитику, и умеешь играть на баяне. Это круто! Теперь посмотрим, какие вакансии в "Звуке" могут подойти тебе. Поехали! 🚀
#
# ---
#
# ### 🎧 **Вакансия 1: Менеджер по маркетингу, интернет-маркетолог**
# **Что нужно:** Опыт от 3 до 6 лет, навыки интернет-маркетинга.
# **Что они делают:** Привлекают пользователей, чтобы все больше людей узнали о "Звуке".
# **Твой баян здесь:** Если ты любишь музыку, но не имеешь опыта в маркетинге, это может быть сложно. Но если у тебя есть опыт в продвижении музыкальных проектов — почему бы нет? 🎶
# **Что не хватает:** Навыки интернет-маркетинга (SMM, SEO, Google Analytics и т.д.). Если их нет — пора их приобрести! 📈
#
# ---
#
# ### 📊 **Вакансии 2 и 3: Бизнес-аналитик**
# **Что нужно:** Опыт от 3 до 6 лет, SQL.
# **Что они делают:** Анализ метаданных, чтобы слушателям было комфортно находить новую музыку.
# **Твой баян здесь:** Если ты любишь аналитику и музыку, это идеально! Но если ты только начинаешь, 3 года опыта могут стать проблемой.
# **Что не хватает:** Навыки работы с данными (SQL, аналитическое мышление). Если их нет — пора их получить! 📚
#
# ---
#
# ### 🧠 **Вакансия 4: Дата-сайентист**
# **Что нужно:** От 1 до 3 лет опыта, Python, SQL, машинное обучение.
# **Что они делают:** Разрабатывают рекомендательные системы для музыки.
# **Твой баян здесь:** Если ты любишь математику и музыку, это мечта! Но если ты не умеешь программировать на Python или работать с машинным обучением — придется учиться.
# **Что не хватает:** Технические навыки (Python, scikit-learn, PyTorch и т.д.). Если их нет — пора их изучить! 🤖
#
# ---
#
# ### 📈 **Вакансия 5: BI-аналитик, аналитик данных**
# **Что нужно:** От 1 до 3 лет опыта, Python, SQL, Pandas, PySpark.
# **Что они делают:** Анализ данных о поиске музыки, чтобы улучшить пользовательский опыт.
# **Твой баян здесь:** Если ты любишь анализировать данные и музыку, это идеально! Но если ты не умеешь работать с Python или SQL — придется учиться.
# **Что не хватает:** Технические навыки (Python, SQL, Pandas и т.д.). Если их нет — пора их приобрести! 📊
#
# ---
#
# ### 💡 **Твой план действий**
# 1. **Определись с ролью:**
#    - Если ты любишь аналитику и музыку, смотрю на вакансии 2, 3 или 5.
#    - Если ты любишь маркетинг и музыку, смотрю на вакансию 1.
#    - Если ты любишь математику и музыку, смотрю на вакансию 4.
#
# 2. **Приобрети навыки:**
#    - Если ты не умеешь работать с данными, начни с SQL и Python.
#    - Если ты не умеешь анализировать данные, научись работать с Pandas и PySpark.
#    - Если ты не умеешь делать визуализацию данных, научись работать с Tableau или Plotly.
#
# 3. **Начни с малого:**
#    - Если у тебя нет опыта, начни с младших позиций.
#    - Если ты умеешь играть на баяне, это может быть плюсом — возможно, тебя возьмут наProbation, чтобы ты показал свои навыки.
#
# ---
#
# ### 🎤 **Твое преимущество**
# Ты любишь музыку и аналитику — это идеальное сочетание для работы в "Звуке"! Если ты готов учиться и развиваться, ты обязательно найдешь свою вакансию. Удачи! 🎧

# %%
def demonstrate_rag_step_by_step(query: str):
    """Демонстрация работы RAG цепочки по шагам с промежуточными результатами"""

    print("🔍 ПОШАГОВОЕ ВЫПОЛНЕНИЕ RAG ЦЕПОЧКИ")
    print("=" * 60)
    print(f"📝 Запрос: '{query}'")
    print()

    # ШАГ 1: Получение контекста из векторной БД
    print("📍 ШАГ 1: Поиск похожих документов")
    print("-" * 40)

    # Получаем документы из ретривера
    docs = retriever.invoke(query)
    print(f"🔢 Найдено документов: {len(docs)}")

    for i, doc in enumerate(docs, 1):
        print(f"  📄 Документ {i}:")
        print(f"     Содержимое: {doc.page_content[:100]}...")
        print(f"     Метаданные: {doc.metadata}")
        print()

    # ШАГ 2: Форматирование документов
    print("📍 ШАГ 2: Форматирование контекста")
    print("-" * 40)

    formatted_context = format_docs(docs)
    print(f"📝 Отформатированный контекст:")
    print(f"{formatted_context[:500]}...")
    print()

    # ШАГ 3: Создание входных данных для промпта
    print("📍 ШАГ 3: Подготовка входных данных")
    print("-" * 40)

    input_data = {
        "context": formatted_context,
        "question": query
    }
    print(f"🗂️ Входные данные:")
    print(f"   📋 Контекст: {len(formatted_context)} символов")
    print(f"   ❓ Вопрос: '{input_data['question']}'")
    print()

    # ШАГ 4: Применение промпта
    print("📍 ШАГ 4: Создание финального промпта")
    print("-" * 40)

    formatted_prompt = rag_prompt.format(**input_data)
    print(f"💬 Финальный промпт для LLM:")
    print(f"{formatted_prompt[:800]}...")
    print()

    # ШАГ 5: Вызов LLM
    print("📍 ШАГ 5: Генерация ответа LLM")
    print("-" * 40)

    # Конвертируем промпт в сообщения
    messages = rag_prompt.format_messages(**input_data)
    print(f"📨 Отправляем {len(messages)} сообщений в LLM")

    # Получаем ответ
    response = llm.invoke(messages)
    print(f"🤖 Сырой ответ LLM:")
    print(f"   Тип: {type(response)}")
    print(f"   Содержимое: {response.content[:200]}...")
    print()

    # ШАГ 6: Парсинг ответа
    print("📍 ШАГ 6: Финальная обработка")
    print("-" * 40)

    final_answer = StrOutputParser().parse(response)
    print(f"✅ Финальный ответ:")
    print(f"{final_answer}")

    return final_answer

# %%
demonstrate_rag_step_by_step(query)
# Out:
# 🔍 ПОШАГОВОЕ ВЫПОЛНЕНИЕ RAG ЦЕПОЧКИ
# ============================================================
# 📝 Запрос: 'Играю на баяне'
#
# 📍 ШАГ 1: Поиск похожих документов
# ----------------------------------------
# 🔢 Найдено документов: 5
#   📄 Документ 1:
#      Содержимое: Миссия роли Музыка объединяет людей, вдохновляет и делает жизнь ярче. В Звуке мы создаем сервис, кот...
#      Метаданные: {'employer': 'Звук', 'professional_roles': 'Менеджер по маркетингу, интернет-маркетолог', 'experience': 'От 3 до 6 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Полный день', 'extracted_skills': [], 'source': 'vacancy', 'published_at': '2025-05-30T11:18:10+0300', 'alternate_url': 'https://hh.ru/vacancy/121160863', 'has_языки': False, 'has_библиотеки_ML': False, 'has_обработка_данных': False, 'has_визуализация': False, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 0, '_id': '7d532b1d-a170-472f-9060-ec4684cce59a', '_collection_name': 'demo_collection'}
#
#   📄 Документ 2:
#      Содержимое: О твоей роли Команда Анализа Контента помогает смежным командам Звука предоставлять слушателям комфо...
#      Метаданные: {'employer': 'Звук', 'professional_roles': 'Бизнес-аналитик', 'experience': 'От 3 до 6 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Удаленная работа', 'extracted_skills': ['SQL'], 'source': 'vacancy', 'published_at': '2025-05-29T17:57:20+0300', 'alternate_url': 'https://hh.ru/vacancy/121144071', 'has_языки': True, 'has_библиотеки_ML': False, 'has_обработка_данных': False, 'has_визуализация': False, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 1, '_id': '9648e3b9-9e61-4017-a2f7-9033c44ffca1', '_collection_name': 'demo_collection'}
#
#   📄 Документ 3:
#      Содержимое: О твоей роли Команда Анализа Контента помогает смежным командам Звука предоставлять слушателям комфо...
#      Метаданные: {'employer': 'Звук', 'professional_roles': 'Бизнес-аналитик', 'experience': 'От 3 до 6 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Удаленная работа', 'extracted_skills': ['SQL'], 'source': 'vacancy', 'published_at': '2025-04-21T17:34:19+0300', 'alternate_url': 'https://hh.ru/vacancy/118456818', 'has_языки': True, 'has_библиотеки_ML': False, 'has_обработка_данных': False, 'has_визуализация': False, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 1, '_id': '5a30be2c-3ea8-4545-9397-7778e67f3f18', '_collection_name': 'demo_collection'}
#
#   📄 Документ 4:
#      Содержимое: Привет! Мы в Звуке ищем Дата аналитика поиска. Мы - команда дата аналитики в отделе ML, хотим лучше ...
#      Метаданные: {'employer': 'Звук', 'professional_roles': 'BI-аналитик, аналитик данных', 'experience': 'От 3 до 6 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Удаленная работа', 'extracted_skills': ['Python', 'SQL', 'Pandas', 'PySpark', 'Hadoop', 'Matplotlib', 'Seaborn', 'Plotly', 'Tableau'], 'source': 'vacancy', 'published_at': '2025-04-21T15:24:55+0300', 'alternate_url': 'https://hh.ru/vacancy/119777870', 'has_языки': True, 'has_библиотеки_ML': False, 'has_обработка_данных': True, 'has_визуализация': True, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 9, '_id': '860cb112-9138-45e2-a3ad-9dc19343e7a3', '_collection_name': 'demo_collection'}
#
#   📄 Документ 5:
#      Содержимое: Guitado — самая большая в Москве школа музыки, где каждый ученик, от начинающего до продвинутого, на...
#      Метаданные: {'employer': 'GUITARDO', 'professional_roles': 'Менеджер по маркетингу, интернет-маркетолог', 'experience': 'От 3 до 6 лет', 'area': 'Москва', 'salary': nan, 'schedule': 'Удаленная работа', 'extracted_skills': [], 'source': 'vacancy', 'published_at': '2025-04-25T14:55:27+0300', 'alternate_url': 'https://hh.ru/vacancy/119827011', 'has_языки': False, 'has_библиотеки_ML': False, 'has_обработка_данных': False, 'has_визуализация': False, 'has_NLP': False, 'has_CV': False, 'has_MLOps': False, 'has_базы_данных': False, 'skills_count': 0, '_id': '1f00330e-afcb-4bc3-b027-cda187b12ce4', '_collection_name': 'demo_collection'}
#
# 📍 ШАГ 2: Форматирование контекста
# ----------------------------------------
# 📝 Отформатированный контекст:
#
#         === ВАКАНСИЯ 1 ===
#         Должность: Менеджер по маркетингу, интернет-маркетолог
#         Компания: Звук
#         Опыт: От 3 до 6 лет
#         Локация: Москва
#         График: Полный день
#         Навыки:
#         Ссылка: https://hh.ru/vacancy/121160863
#
#         Описание: Миссия роли Музыка объединяет людей, вдохновляет и делает жизнь ярче. В Звуке мы создаем сервис, который помогает каждому найти свой ритм и открыть новые горизонты в мире аудио — от любимых треков до подкастов и аудиокниг....
#
# 📍 ШАГ 3: Подготовка входных данных
# ----------------------------------------
# 🗂️ Входные данные:
#    📋 Контекст: 2987 символов
#    ❓ Вопрос: 'Играю на баяне'
#
# 📍 ШАГ 4: Создание финального промпта
# ----------------------------------------
# 💬 Финальный промпт для LLM:
# System: Ты эксперт-аналитик рынка IT-вакансий с многолетним опытом и отличным чувством юмора! 🎯
#     Твоя задача - проанализировать предоставленные вакансии и дать профессиональную оценку с долей иронии.
#
#     Стиль анализа:
#     - Проводи глубокий анализ, но с легкой иронией над IT-реалиями
#     - Используй IT-мемы и шутки там, где это уместно
#     - Подмечай забавные особенности вакансий (завышенные требования, смешные формулировки)
#     - Давай практические советы с юмором
#     - Структурируй ответ с эмодзи и забавными комментариями
#     - Отвечай на русском языке живым, но профессиональным тоном
#
#     Помни: юмор должен быть добрым и не оскорбительным. Цель - сделать анализ интересным!
#
#     Если среди вакансий есть что-то особенно забавное - обязательно это отметь! 😄
# Human: 📊 ДАННЫЕ ДЛЯ АНАЛИЗА...
#
# 📍 ШАГ 5: Генерация ответа LLM
# ----------------------------------------
# 📨 Отправляем 2 сообщений в LLM
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1750: FutureWarning: `encoder_attention_mask` is deprecated and will be removed in version 4.55.0 for `XLMRobertaSdpaSelfAttention.forward`.
#   return forward_call(*args, **kwargs)
# 🤖 Сырой ответ LLM:
#    Тип: <class 'langchain_core.messages.ai.AIMessage'>
#    Содержимое: <think>
# Хорошо, я получил задание проанализировать пять вакансий для компании "Звук" и "GUITARDO", учитывая, что я играю на баяне. Мне нужно подойти к этому с юмором и профессиональным взглядом.
#
# Снач...
#
# 📍 ШАГ 6: Финальная обработка
# ----------------------------------------
# ✅ Финальный ответ:
# content='<think>\nХорошо, я получил задание проанализировать пять вакансий для компании "Звук" и "GUITARDO", учитывая, что я играю на баяне. Мне нужно подойти к этому с юмором и профессиональным взглядом.\n\nСначала я посмотрю на каждую вакансию по отдельности. Вакансия 1 ищет маркетолога с опытом 3-6 лет. Описание говорит о миссии объединять людей через музыку. Мне кажется, здесь важен опыт в интернет-маркетинге, возможно, знание музыкальной индустрии. Юмористически можно сравнить это с поиском идеальной мелодии для кампании.\n\nВакансии 2 и 3 обе ищут бизнес-аналитиков с знанием SQL. Обе описывают работу в команде анализа контента для улучшения пользовательского опыта. Возможно, здесь нужен аналитический ум и внимание к деталям. Шутка про SQL и таблицы может быть уместна.\n\nВакансия 4 ищет BI-аналитика с множеством навыков: Python, Pandas, Tableau и т.д. Это уже более техническая позиция, требующая глубоких знаний в данных и визуализации. Можно пошутил о том, что от кандидата требуется быть "волшебником данных".\n\nВакансия 5 снова маркетолог, но для музыкальной школы. Здесь важно понимание аудитории и опыт в продвижении образовательных услуг. Юмористически можно сравнить это с настройкой гитары для идеального аккорда.\n\nТеперь, учитывая, что я играю на баяне, возможно, это не напрямую связано с вакансиями, но можно обыграть это в шутках или метафорах, связанных с музыкой и инструментами.\n\nНужно структурировать ответ с эмодзи, разделить на пункты, добавить практические советы с юмором и не забыть про добрый юмор без оскорблений.\n\nВ итоге, я подготовлю анализ каждой вакансии с соответствующими шутками и советами, подчеркнув важные моменты и особенности каждой позиции.\n</think>\n\n🎸 **Вакансия 1: Менеджер по маркетингу, интернет-маркетолог в "Звук"**  \n🎶 **Миссия:** Объединять людей через музыку. Если вы умеете находить идеальную мелодию для маркетинговой кампании, это ваша вакансия!  \n💡 **Советы:** Продавайте не просто музыку, а эмоции. Ваши кампании должны быть как идеально настроенный баян — резонировать с аудиторией.  \n\n🎸 **Вакансии 2 и 3: Бизнес-аналитик в "Звук"**  \n🎶 **Миссия:** Анализ данных для улучшения пользовательского опыта. Если вы видите музыку в цифрах,欢迎来！  \n💡 **Советы:** Учите SQL, чтобы таблицы пели как хорошо настроенный баян. Анализ данных — это как поиск правильного аккорда в песне.  \n\n🎸 **Вакансия 4: BI-аналитик в "Звук"**  \n🎶 **Миссия:** Волшебство с данными. Если вы знаете Python и Tableau, вы уже半个 волшебник.  \n💡 **Советы:** Делайте данные красивыми, как музыка. Визуализация должна быть такой же привлекательной, как концертный выступление.  \n\n🎸 **Вакансия 5: Менеджер по маркетингу в "GUITARDO"**  \n🎶 **Миссия:** Продавать музыкальное обучение. Если вы знаете, как настроить гитару и аудиторию, это ваш шанс.  \n💡 **Советы:** Маркетинг здесь — как настройка инструмента. Найдите правильный аккорд с вашей аудиторией.  \n\n🎶 **Общие советы:**  \n- Если вы играете на баяне, не стесняйтесь упомянуть это в резюме. Ваши навыки работы с музыкой могут стать вашим конкурентным преимуществом.  \n- Удачи, и пусть ваша карьера будет такой же гармоничной, как ваше исполнение на баяне! 🎵' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 1090, 'prompt_tokens': 1274, 'total_tokens': 2364, 'completion_time': 4.650450451, 'prompt_time': 0.12551874, 'queue_time': 2.409228844, 'total_time': 4.775969191}, 'model_name': 'deepseek-r1-distill-llama-70b', 'system_fingerprint': 'fp_1bbe7845ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None} id='run--87bf438a-8663-432e-8d2b-990bc1e0cc97-0' usage_metadata={'input_tokens': 1274, 'output_tokens': 1090, 'total_tokens': 2364}
# AIMessage(content='<think>\nХорошо, я получил задание проанализировать пять вакансий для компании "Звук" и "GUITARDO", учитывая, что я играю на баяне. Мне нужно подойти к этому с юмором и профессиональным взглядом.\n\nСначала я посмотрю на каждую вакансию по отдельности. Вакансия 1 ищет маркетолога с опытом 3-6 лет. Описание говорит о миссии объединять людей через музыку. Мне кажется, здесь важен опыт в интернет-маркетинге, возможно, знание музыкальной индустрии. Юмористически можно сравнить это с поиском идеальной мелодии для кампании.\n\nВакансии 2 и 3 обе ищут бизнес-аналитиков с знанием SQL. Обе описывают работу в команде анализа контента для улучшения пользовательского опыта. Возможно, здесь нужен аналитический ум и внимание к деталям. Шутка про SQL и таблицы может быть уместна.\n\nВакансия 4 ищет BI-аналитика с множеством навыков: Python, Pandas, Tableau и т.д. Это уже более техническая позиция, требующая глубоких знаний в данных и визуализации. Можно пошутил о том, что от кандидата требуется быть "волшебником данных".\n\nВакансия 5 снова маркетолог, но для музыкальной школы. Здесь важно понимание аудитории и опыт в продвижении образовательных услуг. Юмористически можно сравнить это с настройкой гитары для идеального аккорда.\n\nТеперь, учитывая, что я играю на баяне, возможно, это не напрямую связано с вакансиями, но можно обыграть это в шутках или метафорах, связанных с музыкой и инструментами.\n\nНужно структурировать ответ с эмодзи, разделить на пункты, добавить практические советы с юмором и не забыть про добрый юмор без оскорблений.\n\nВ итоге, я подготовлю анализ каждой вакансии с соответствующими шутками и советами, подчеркнув важные моменты и особенности каждой позиции.\n</think>\n\n🎸 **Вакансия 1: Менеджер по маркетингу, интернет-маркетолог в "Звук"**  \n🎶 **Миссия:** Объединять людей через музыку. Если вы умеете находить идеальную мелодию для маркетинговой кампании, это ваша вакансия!  \n💡 **Советы:** Продавайте не просто музыку, а эмоции. Ваши кампании должны быть как идеально настроенный баян — резонировать с аудиторией.  \n\n🎸 **Вакансии 2 и 3: Бизнес-аналитик в "Звук"**  \n🎶 **Миссия:** Анализ данных для улучшения пользовательского опыта. Если вы видите музыку в цифрах,欢迎来！  \n💡 **Советы:** Учите SQL, чтобы таблицы пели как хорошо настроенный баян. Анализ данных — это как поиск правильного аккорда в песне.  \n\n🎸 **Вакансия 4: BI-аналитик в "Звук"**  \n🎶 **Миссия:** Волшебство с данными. Если вы знаете Python и Tableau, вы уже半个 волшебник.  \n💡 **Советы:** Делайте данные красивыми, как музыка. Визуализация должна быть такой же привлекательной, как концертный выступление.  \n\n🎸 **Вакансия 5: Менеджер по маркетингу в "GUITARDO"**  \n🎶 **Миссия:** Продавать музыкальное обучение. Если вы знаете, как настроить гитару и аудиторию, это ваш шанс.  \n💡 **Советы:** Маркетинг здесь — как настройка инструмента. Найдите правильный аккорд с вашей аудиторией.  \n\n🎶 **Общие советы:**  \n- Если вы играете на баяне, не стесняйтесь упомянуть это в резюме. Ваши навыки работы с музыкой могут стать вашим конкурентным преимуществом.  \n- Удачи, и пусть ваша карьера будет такой же гармоничной, как ваше исполнение на баяне! 🎵', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 1090, 'prompt_tokens': 1274, 'total_tokens': 2364, 'completion_time': 4.650450451, 'prompt_time': 0.12551874, 'queue_time': 2.409228844, 'total_time': 4.775969191}, 'model_name': 'deepseek-r1-distill-llama-70b', 'system_fingerprint': 'fp_1bbe7845ec', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None}, id='run--87bf438a-8663-432e-8d2b-990bc1e0cc97-0', usage_metadata={'input_tokens': 1274, 'output_tokens': 1090, 'total_tokens': 2364})
